# %%
import os
if not hasattr(os, "_cwd"):
    os.chdir("../../")
    os._cwd = True

# %%
from pymongo import AsyncMongoClient

from server.Environment import *


class MongoDB:

    async def list_collection_names(self):
        return await self.db.list_collection_names()
    

    client = AsyncMongoClient(
        DATABASE_URL,
        connectTimeoutMS=5000,  # 5 second timeout for initial connection
        serverSelectionTimeoutMS=5000,  # 5 second timeout for server selection
    )

    db = client["database"]


    c_credential = db["c_credential"]
    c_credential_reset_otp = db["c_credential_reset_otp"]
    c_credential_signup_otp = db["c_credential_signup_otp"]

    c_attendance = db["c_attendance"]
    c_attendance_code = db["c_attendance_code"]

    c_class_name = db["c_class_name"]

    c_class_type = db["c_class_type"]

    c_contributor = db["c_contributor"]

    c_counter = db["c_counter"]

    v_attendance = db["v_attendance"]

    c_template = db["c_template"]

########## __________ ##########


db = MongoDB()

# await db.list_collection_names()
await db.list_collection_names()
# Out:
# ['collection_credential']

# %%
from pymongo import MongoClient


print(f"DATABASE_URL : {DATABASE_URL}")


client = MongoClient(
        DATABASE_URL,
        connectTimeoutMS=5000,  # 5 second timeout for initial connection
        serverSelectionTimeoutMS=5000,  # 5 second timeout for server selection
    )

db = client['database']

c_credential = db["collection_credential"]
c_credential_otp = db["collection_credential_otp"]
c_attendance = db["collection_attendance"]
c_attendance_code = db["collection_attendance_code"]
c_class = db["collection_class"]
c_class_type = db["collection_class_type"]

c_credential.insert_one({})
# Out:
# DATABASE_URL : mongodb://admin:adminadmin@127.0.0.1:27017
# InsertOneResult(ObjectId('6996e3109bfd1afa5f8a0def'), acknowledged=True)

# %%
client = AsyncMongoClient(
        DATABASE_URL,
        connectTimeoutMS=5000,  # 5 second timeout for initial connection
        serverSelectionTimeoutMS=5000,  # 5 second timeout for server selection
    )


db = client['xxx']

# Create a collection and insert a document
collection = db['my_collection']
document = {"name": "John", "age": 30}
result = await collection.insert_one(document)

print(f"Database created: {db.name}")
print(f"Collection created: {collection.name}")
print(f"Inserted document ID: {result.inserted_id}")

# List all databases
databases = await client.admin.command('listDatabases')
print(f"Available databases: {databases}")

# Close the connection
# client.close()
# Out:
# Database created: xxx
# Collection created: my_collection
# Inserted document ID: 6996e2389bfd1afa5f8a0de8
# Available databases: {'databases': [{'name': 'admin', 'sizeOnDisk': 102400, 'empty': False}, {'name': 'afasfd', 'sizeOnDisk': 8192, 'empty': False}, {'name': 'config', 'sizeOnDisk': 110592, 'empty': False}, {'name': 'local', 'sizeOnDisk': 65536, 'empty': False}, {'name': 'my_database', 'sizeOnDisk': 40960, 'empty': False}, {'name': 'xxx', 'sizeOnDisk': 8192, 'empty': False}], 'totalSize': 335872, 'totalSizeMb': 0, 'ok': 1.0}

# %%
db_aaa = client["aaa"]
db_aaa.create_collection("bbb")
await db_aaa.list_collection_names()
# Out:
# C:\Users\muysengly\AppData\Local\Temp\ipykernel_26904\1189298453.py:2: RuntimeWarning: coroutine 'AsyncDatabase.create_collection' was never awaited
#   db_aaa.create_collection("bbb")
# ...
# []

# %%
client.flush()
client.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 client.flush()
#       2 client.close()
#
# TypeError: 'AsyncDatabase' object is not callable

# %%
# create a database in MongoDB (MongoDB creates databases/collections on first insert)
db = client["database"]
db.create_collection("collection_credential")
# Out:
# <coroutine object AsyncDatabase.create_collection at 0x0000025B06158C40>

# %%
db = client["database"]
db
# Out:
# AsyncDatabase(AsyncMongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True, connecttimeoutms=5000, serverselectiontimeoutms=5000), 'database')

# %%
await db.list_collection_names()
# Out:
# []

# %%
c_credential = db["collection_credential"]
# To show all data in the collection, use find() and convert the cursor to a list
docs = await c_credential.find().to_list(length=None)
docs
# Out:
# []
